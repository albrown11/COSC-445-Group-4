# %% [markdown]
# The code is in the first cell, I have the code written a few times to show that the hashes do or do not match. The code is commented so it is easy to follow even if you are not familiar with python.
#
# Also at the bottom is a small database I was working on you can ignore it, but if I remember from my research hashes are supposed to be matched against other hashes not decrypted but I can b mistaken.

# %% [markdown]
# Definition of the function crypto that creates a hashing algorithm
# First run of the crypto function

# %%
import pandas as pd
import os
import numpy as np
import sqlite3
import sqlalchemy
import random 

#defining a function named crypto 
def crypto(): 
    #having user enter a plaintext message
    Plain_text= input("Enter a message to convert: \n")

    #shouldnt use this for encryption geek for geeks says because it will give the same random number each time but it may be helpful for our key
    #random.seed(7)

    size= len(Plain_text)

    #setting K as a random int
    k= (random.randint(1, 999999999999)) % 100 +1
    print(k, '\n')

    #setting list
    abcs=[]
    avalue=[]
    hvalue=[]
    keys= []
    hexkey= []
    ravalue= []
    hex_key=[]
    rakey=[]
    rahvalue= []

    count= 0 

    if (k % 2 == 0 or k % 3 == 0 or k % 5 == 0 or k % 7 == 0):
        k= random.randint(1, 999999999999) % 100 + 1
    for i in Plain_text:
        print("\n", i, ord(i), hex(ord(i)))
        #characters added to a list
        abcs.append(i)
        #ascii value added to a lis
        avalue.append(ord(i))
        #acii value plus (size^size-1)%128
        ravalue.append(ord(i)+ pow(size,size-1,128))
        #hexi value of ascii value
        hvalue.append(hex(ord(i)))
        #hexi value of ascii value plus (size ^ size-1)%128
        rahvalue.append(hex(ord(i)+ pow(size,size-1,128)))
        
        if(count==0):
            #adding the first ascii value to a list of keys 
            keys.append(avalue[count])
            #adding the first hex value of the ascii value to  a list of keys
            hexkey.append(hex(avalue[count]))
            #adding the first ascii value plus ... to a list of keys
            rakey.append(ravalue[count])
            #adding the first hex value of the ascii value plus ... to a list of keys
            hex_key.append(hex(ravalue[count]))
        else:
            #adding a key to the list by multiplying the current ascii value by the previous key cell value
            keys.append(avalue[count]* keys[count- 1])
            #adding a hex key to the list by concating the previous key value to the hex value of 
            #the current asciii value of the character times the previous ascii key cell
            hexkey.append(hexkey[count- 1]+ hex(avalue[count]* keys[count- 1]))
            #adding a key to the list by multiplying the current ascii value plus... by the previous rakey cell value 
            rakey.append(ravalue[count]* rakey[count-1])
            #adding a hex key to the list by concating the previous key value to the hex value of 
            #the current ravalue of the character times the previous rakey cell
            hex_key.append(hex_key[count- 1]+ hex(ravalue[count]* rakey[count- 1]))
        print(abcs)
        print(avalue)
        print(ravalue)
        print(hvalue)
        print(keys)
        print(hexkey)
        print(rakey)
        print(hex_key)
    
    
        #incrimenting count 
        count= count +1
    print("Key is: ", keys[size-1])
    print("Hex Key is: ", hex(keys[size-1]))
    print("HexKey is: ", hexkey[size-1])
    print("Hex_Key is: ", hex_key[size-1])
    return [hex_key, size]
#First run of the program using Hello 


hex_key, size= crypto()
check1= hex_key[size-1]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\tysco\cryptography\COSC-445-Group-4\.ipynb_checkpoints\cryptography-checkpoint.ipynb Cell 3 in <cell line: 90>()
#      <a href='vscode-notebook-cell:/c%3A/Users/tysco/cryptography/COSC-445-Group-4/.ipynb_checkpoints/cryptography-checkpoint.ipynb#W2sZmlsZQ%3D%3D?line=85'>86</a>     return [hex_key, size]
#      <a href='vscode-notebook-cell:/c%3A/Users/tysco/cryptography/COSC-445-Group-4/.ipynb_checkpoints/cryptography-checkpoint.ipynb#W2sZmlsZQ%3D%3D?line=86'>87</a> #First run of the program using Hello
# ---> <a href='vscode-notebook-cell:/c%3A/Users/tysco/cryptography/COSC-445-Group-4/.ipynb_checkpoints/cryptography-checkpoint.ipynb#W2sZmlsZQ%3D%3D?line=89'>90</a> hex_key, size= crypto()
#      <a href='vscode-notebook-cell:/c%3A/Users/tysco/cryptography/COSC-445-Group-4/.ipynb_checkpoints/cryptography-checkpoint.ipynb#W2sZmlsZQ%3D%3D?line=90'>91</a> check1= hex_key[size-1]
#
# c:\Users\tysco\cryptography\COSC-445-Group-4\.ipynb_checkpoints\cryptography-checkpoint.ipynb Cell 3 in crypto()
#       <a href='vscode-notebook-cell:/c%3A/Users/tysco/cryptography/COSC-445-Group-4/.ipynb_checkpoints/cryptography-checkpoint.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a> def crypto():
#      <a href='vscode-notebook-cell:/c%3A/Users/tysco/cryptography/COSC-445-Group-4/.ipynb_checkpoints/cryptography-checkpoint.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a>     #having user enter a plaintext message
# ---> <a href='vscode-notebook-cell:/c%3A/Users/tysco/cryptography/COSC-445-Group-4/.ipynb_checkpoints/cryptography-checkpoint.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a>     Plain_text= input("Enter a message to convert: \n")
#      <a href='vscode-notebook-cell:/c%3A/Users/tysco/cryptography/COSC-445-Group-4/.ipynb_checkpoints/cryptography-checkpoint.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a>     #shouldnt use this for encryption geek for geeks says because it will give the same random number each time but it may be helpful for our key
#      <a href='vscode-notebook-cell:/c%3A/Users/tysco/cryptography/COSC-445-Group-4/.ipynb_checkpoints/cryptography-checkpoint.ipynb#W2sZmlsZQ%3D%3D?line=13'>14</a>     #random.seed(7)
#      <a href='vscode-notebook-cell:/c%3A/Users/tysco/cryptography/COSC-445-Group-4/.ipynb_checkpoints/cryptography-checkpoint.ipynb#W2sZmlsZQ%3D%3D?line=15'>16</a>     size= len(Plain_text)
#
# File c:\Users\tysco\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py:1177, in Kernel.raw_input(self, prompt)
#    1173 if not self._allow_stdin:
#    1174     raise StdinNotImplementedError(
#    1175         "raw_input was called, but this frontend does not support input requests."
#    1176     )
# -> 1177 return self._input_request(
#    1178     str(prompt),
#    1179     self._parent_ident["shell"],
#    1180     self.get_parent("shell"),
#    1181     password=False,
#    1182 )
#
# File c:\Users\tysco\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py:1219, in Kernel._input_request(self, prompt, ident, parent, password)
#    1216             break
#    1217 except KeyboardInterrupt:
#    1218     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219     raise KeyboardInterrupt("Interrupted by user") from None
#    1220 except Exception:
#    1221     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# A second run of the program using the text Hello World

# %%
hex_key, size= crypto()
check2= hex_key[size-1]
# Out:
# 58
#
#
#  H 72 0x48
# ['H']
# [72]
# [161]
# ['0x48']
# [72]
# ['0x48']
# [161]
# ['0xa1']
#
#  e 101 0x65
# ['H', 'e']
# [72, 101]
# [161, 190]
# ['0x48', '0x65']
# [72, 7272]
# ['0x48', '0x480x1c68']
# [161, 30590]
# ['0xa1', '0xa10x777e']
#
#  l 108 0x6c
# ['H', 'e', 'l']
# [72, 101, 108]
# [161, 190, 197]
# ['0x48', '0x65', '0x6c']
# [72, 7272, 785376]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0']
# [161, 30590, 6026230]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6']
#
#  l 108 0x6c
# ['H', 'e', 'l', 'l']
# [72, 101, 108, 108]
# [161, 190, 197, 197]
# ['0x48', '0x65', '0x6c', '0x6c']
# [72, 7272, 785376, 84820608]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280']
# [161, 30590, 6026230, 1187167310]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6', '0xa10x777e0x5bf3f60x46c2bc4e']
#
#  o 111 0x6f
# ['H', 'e', 'l', 'l', 'o']
# [72, 101, 108, 108, 111]
# [161, 190, 197, 197, 200]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f']
# [72, 7272, 785376, 84820608, 9415087488]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580']
# [161, 30590, 6026230, 1187167310, 237433462000]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6', '0xa10x777e0x5bf3f60x46c2bc4e', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf0']
#
#    32 0x20
# ['H', 'e', 'l', 'l', 'o', ' ']
# [72, 101, 108, 108, 111, 32]
# [161, 190, 197, 197, 200, 121]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x20']
# [72, 7272, 785376, 84820608, 9415087488, 301282799616]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab000']
# [161, 30590, 6026230, 1187167310, 237433462000, 28729448902000]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6', '0xa10x777e0x5bf3f60x46c2bc4e', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf0', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad70']
#
#  W 87 0x57
# ['H', 'e', 'l', 'l', 'o', ' ', 'W']
# [72, 101, 108, 108, 111, 32, 87]
# [161, 190, 197, 197, 200, 121, 176]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x20', '0x57']
# [72, 7272, 785376, 84820608, 9415087488, 301282799616, 26211603566592]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d000']
# [161, 30590, 6026230, 1187167310, 237433462000, 28729448902000, 5056383006752000]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6', '0xa10x777e0x5bf3f60x46c2bc4e', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf0', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad70', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d00']
#
#  o 111 0x6f
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o']
# [72, 101, 108, 108, 111, 32, 87, 111]
# [161, 190, 197, 197, 200, 121, 176, 200]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x20', '0x57', '0x6f']
# [72, 7272, 785376, 84820608, 9415087488, 301282799616, 26211603566592, 2909487995891712]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000xa5629f6793000']
# [161, 30590, 6026230, 1187167310, 237433462000, 28729448902000, 5056383006752000, 1011276601350400000]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6', '0xa10x777e0x5bf3f60x46c2bc4e', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf0', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad70', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d00', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a800']
#
#  r 114 0x72
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r']
# [72, 101, 108, 108, 111, 32, 87, 111, 114]
# [161, 190, 197, 197, 200, 121, 176, 200, 203]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x20', '0x57', '0x6f', '0x72']
# [72, 7272, 785376, 84820608, 9415087488, 301282799616, 26211603566592, 2909487995891712, 331681631531655168]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000xa5629f6793000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000xa5629f67930000x49a5eafc1f76000']
# [161, 30590, 6026230, 1187167310, 237433462000, 28729448902000, 5056383006752000, 1011276601350400000, 205289150074131200000]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6', '0xa10x777e0x5bf3f60x46c2bc4e', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf0', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad70', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d00', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a800', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a8000xb20f59252ea723800']
#
#  l 108 0x6c
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l']
# [72, 101, 108, 108, 111, 32, 87, 111, 114, 108]
# [161, 190, 197, 197, 200, 121, 176, 200, 203, 197]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x20', '0x57', '0x6f', '0x72', '0x6c']
# [72, 7272, 785376, 84820608, 9415087488, 301282799616, 26211603566592, 2909487995891712, 331681631531655168, 35821616205418758144]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000xa5629f6793000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000xa5629f67930000x49a5eafc1f76000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000xa5629f67930000x49a5eafc1f760000x1f11ff225d45c8000']
# [161, 30590, 6026230, 1187167310, 237433462000, 28729448902000, 5056383006752000, 1011276601350400000, 205289150074131200000, 40441962564603846400000]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6', '0xa10x777e0x5bf3f60x46c2bc4e', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf0', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad70', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d00', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a800', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a8000xb20f59252ea723800', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a8000xb20f59252ea7238000x8905cf999ce69e51800']
#
#  d 100 0x64
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd']
# [72, 101, 108, 108, 111, 32, 87, 111, 114, 108, 100]
# [161, 190, 197, 197, 200, 121, 176, 200, 203, 197, 189]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x20', '0x57', '0x6f', '0x72', '0x6c', '0x64']
# [72, 7272, 785376, 84820608, 9415087488, 301282799616, 26211603566592, 2909487995891712, 331681631531655168, 35821616205418758144, 3582161620541875814400]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000xa5629f6793000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000xa5629f67930000x49a5eafc1f76000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000xa5629f67930000x49a5eafc1f760000x1f11ff225d45c8000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000xa5629f67930000x49a5eafc1f760000x1f11ff225d45c80000xc2307a96c6f4220000']
# [161, 30590, 6026230, 1187167310, 237433462000, 28729448902000, 5056383006752000, 1011276601350400000, 205289150074131200000, 40441962564603846400000, 7643530924710126969600000]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6', '0xa10x777e0x5bf3f60x46c2bc4e', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf0', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad70', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d00', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a800', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a8000xb20f59252ea723800', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a8000xb20f59252ea7238000x8905cf999ce69e51800', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a8000xb20f59252ea7238000x8905cf999ce69e518000x65294a4468d642e22b800']
# Key is:  3582161620541875814400
# Hex Key is:  0xc2307a96c6f4220000
# HexKey is:  0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000xa5629f67930000x49a5eafc1f760000x1f11ff225d45c80000xc2307a96c6f4220000
# Hex_Key is:  0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a8000xb20f59252ea7238000x8905cf999ce69e518000x65294a4468d642e22b800

# %% [markdown]
# Check is hash 1 and hash 2 are the same

# %%
print(check1)
print(check2)
if(check1==check2):
    print("Hash matches")
else:
    print("Hash does not match")
# Out:
# 0xb90x9aa60x85814e0x7340a0560x64d88c4b40
# 0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a8000xb20f59252ea7238000x8905cf999ce69e518000x65294a4468d642e22b800
# Hash does not match

# %% [markdown]
# Third run of the program using HELLO WORLD

# %%
hex_key, size= crypto()
check3= hex_key[size-1]
# Out:
# 3
#
#
#  H 72 0x48
# ['H']
# [72]
# [161]
# ['0x48']
# [72]
# ['0x48']
# [161]
# ['0xa1']
#
#  E 69 0x45
# ['H', 'E']
# [72, 69]
# [161, 158]
# ['0x48', '0x45']
# [72, 4968]
# ['0x48', '0x480x1368']
# [161, 25438]
# ['0xa1', '0xa10x635e']
#
#  L 76 0x4c
# ['H', 'E', 'L']
# [72, 69, 76]
# [161, 158, 165]
# ['0x48', '0x45', '0x4c']
# [72, 4968, 377568]
# ['0x48', '0x480x1368', '0x480x13680x5c2e0']
# [161, 25438, 4197270]
# ['0xa1', '0xa10x635e', '0xa10x635e0x400b96']
#
#  L 76 0x4c
# ['H', 'E', 'L', 'L']
# [72, 69, 76, 76]
# [161, 158, 165, 165]
# ['0x48', '0x45', '0x4c', '0x4c']
# [72, 4968, 377568, 28695168]
# ['0x48', '0x480x1368', '0x480x13680x5c2e0', '0x480x13680x5c2e00x1b5da80']
# [161, 25438, 4197270, 692549550]
# ['0xa1', '0xa10x635e', '0xa10x635e0x400b96', '0xa10x635e0x400b960x294777ae']
#
#  O 79 0x4f
# ['H', 'E', 'L', 'L', 'O']
# [72, 69, 76, 76, 79]
# [161, 158, 165, 165, 168]
# ['0x48', '0x45', '0x4c', '0x4c', '0x4f']
# [72, 4968, 377568, 28695168, 2266918272]
# ['0x48', '0x480x1368', '0x480x13680x5c2e0', '0x480x13680x5c2e00x1b5da80', '0x480x13680x5c2e00x1b5da800x871e6d80']
# [161, 25438, 4197270, 692549550, 116348324400]
# ['0xa1', '0xa10x635e', '0xa10x635e0x400b96', '0xa10x635e0x400b960x294777ae', '0xa10x635e0x400b960x294777ae0x1b16e68a30']
#
#    32 0x20
# ['H', 'E', 'L', 'L', 'O', ' ']
# [72, 69, 76, 76, 79, 32]
# [161, 158, 165, 165, 168, 121]
# ['0x48', '0x45', '0x4c', '0x4c', '0x4f', '0x20']
# [72, 4968, 377568, 28695168, 2266918272, 72541384704]
# ['0x48', '0x480x1368', '0x480x13680x5c2e0', '0x480x13680x5c2e00x1b5da80', '0x480x13680x5c2e00x1b5da800x871e6d80', '0x480x13680x5c2e00x1b5da800x871e6d800x10e3cdb000']
# [161, 25438, 4197270, 692549550, 116348324400, 14078147252400]
# ['0xa1', '0xa10x635e', '0xa10x635e0x400b96', '0xa10x635e0x400b960x294777ae', '0xa10x635e0x400b960x294777ae0x1b16e68a30', '0xa10x635e0x400b960x294777ae0x1b16e68a300xccdd2f750b0']
#
#  W 87 0x57
# ['H', 'E', 'L', 'L', 'O', ' ', 'W']
# [72, 69, 76, 76, 79, 32, 87]
# [161, 158, 165, 165, 168, 121, 176]
# ['0x48', '0x45', '0x4c', '0x4c', '0x4f', '0x20', '0x57']
# [72, 4968, 377568, 28695168, 2266918272, 72541384704, 6311100469248]
# ['0x48', '0x480x1368', '0x480x13680x5c2e0', '0x480x13680x5c2e00x1b5da80', '0x480x13680x5c2e00x1b5da800x871e6d80', '0x480x13680x5c2e00x1b5da800x871e6d800x10e3cdb000', '0x480x13680x5c2e00x1b5da800x871e6d800x10e3cdb0000x5bd6ae6d000']
# [161, 25438, 4197270, 692549550, 116348324400, 14078147252400, 2477753916422400]
# ['0xa1', '0xa10x635e', '0xa10x635e0x400b96', '0xa10x635e0x400b960x294777ae', '0xa10x635e0x400b960x294777ae0x1b16e68a30', '0xa10x635e0x400b960x294777ae0x1b16e68a300xccdd2f750b0', '0xa10x635e0x400b960x294777ae0x1b16e68a300xccdd2f750b00x8cd810a077900']
#
#  O 79 0x4f
# ['H', 'E', 'L', 'L', 'O', ' ', 'W', 'O']
# [72, 69, 76, 76, 79, 32, 87, 79]
# [161, 158, 165, 165, 168, 121, 176, 168]
# ['0x48', '0x45', '0x4c', '0x4c', '0x4f', '0x20', '0x57', '0x4f']
# [72, 4968, 377568, 28695168, 2266918272, 72541384704, 6311100469248, 498576937070592]
# ['0x48', '0x480x1368', '0x480x13680x5c2e0', '0x480x13680x5c2e00x1b5da80', '0x480x13680x5c2e00x1b5da800x871e6d80', '0x480x13680x5c2e00x1b5da800x871e6d800x10e3cdb000', '0x480x13680x5c2e00x1b5da800x871e6d800x10e3cdb0000x5bd6ae6d000', '0x480x13680x5c2e00x1b5da800x871e6d800x10e3cdb0000x5bd6ae6d0000x1c573fd3a3000']
# [161, 25438, 4197270, 692549550, 116348324400, 14078147252400, 2477753916422400, 416262657958963200]
# ['0xa1', '0xa10x635e', '0xa10x635e0x400b96', '0xa10x635e0x400b960x294777ae', '0xa10x635e0x400b960x294777ae0x1b16e68a30', '0xa10x635e0x400b960x294777ae0x1b16e68a300xccdd2f750b0', '0xa10x635e0x400b960x294777ae0x1b16e68a300xccdd2f750b00x8cd810a077900', '0xa10x635e0x400b960x294777ae0x1b16e68a300xccdd2f750b00x8cd810a0779000x5c6dcae94e76800']
#
#  R 82 0x52
# ['H', 'E', 'L', 'L', 'O', ' ', 'W', 'O', 'R']
# [72, 69, 76, 76, 79, 32, 87, 79, 82]
# [161, 158, 165, 165, 168, 121, 176, 168, 171]
# ['0x48', '0x45', '0x4c', '0x4c', '0x4f', '0x20', '0x57', '0x4f', '0x52']
# [72, 4968, 377568, 28695168, 2266918272, 72541384704, 6311100469248, 498576937070592, 40883308839788544]
# ['0x48', '0x480x1368', '0x480x13680x5c2e0', '0x480x13680x5c2e00x1b5da80', '0x480x13680x5c2e00x1b5da800x871e6d80', '0x480x13680x5c2e00x1b5da800x871e6d800x10e3cdb000', '0x480x13680x5c2e00x1b5da800x871e6d800x10e3cdb0000x5bd6ae6d000', '0x480x13680x5c2e00x1b5da800x871e6d800x10e3cdb0000x5bd6ae6d0000x1c573fd3a3000', '0x480x13680x5c2e00x1b5da800x871e6d800x10e3cdb0000x5bd6ae6d0000x1c573fd3a30000x913f271ca36000']
# [161, 25438, 4197270, 692549550, 116348324400, 14078147252400, 2477753916422400, 416262657958963200, 71180914510982707200]
# ['0xa1', '0xa10x635e', '0xa10x635e0x400b96', '0xa10x635e0x400b960x294777ae', '0xa10x635e0x400b960x294777ae0x1b16e68a30', '0xa10x635e0x400b960x294777ae0x1b16e68a300xccdd2f750b0', '0xa10x635e0x400b960x294777ae0x1b16e68a300xccdd2f750b00x8cd810a077900', '0xa10x635e0x400b960x294777ae0x1b16e68a300xccdd2f750b00x8cd810a0779000x5c6dcae94e76800', '0xa10x635e0x400b960x294777ae0x1b16e68a300xccdd2f750b00x8cd810a0779000x5c6dcae94e768000x3dbd5689d76927800']
#
#  L 76 0x4c
# ['H', 'E', 'L', 'L', 'O', ' ', 'W', 'O', 'R', 'L']
# [72, 69, 76, 76, 79, 32, 87, 79, 82, 76]
# [161, 158, 165, 165, 168, 121, 176, 168, 171, 165]
# ['0x48', '0x45', '0x4c', '0x4c', '0x4f', '0x20', '0x57', '0x4f', '0x52', '0x4c']
# [72, 4968, 377568, 28695168, 2266918272, 72541384704, 6311100469248, 498576937070592, 40883308839788544, 3107131471823929344]
# ['0x48', '0x480x1368', '0x480x13680x5c2e0', '0x480x13680x5c2e00x1b5da80', '0x480x13680x5c2e00x1b5da800x871e6d80', '0x480x13680x5c2e00x1b5da800x871e6d800x10e3cdb000', '0x480x13680x5c2e00x1b5da800x871e6d800x10e3cdb0000x5bd6ae6d000', '0x480x13680x5c2e00x1b5da800x871e6d800x10e3cdb0000x5bd6ae6d0000x1c573fd3a3000', '0x480x13680x5c2e00x1b5da800x871e6d800x10e3cdb0000x5bd6ae6d0000x1c573fd3a30000x913f271ca36000', '0x480x13680x5c2e00x1b5da800x871e6d800x10e3cdb0000x5bd6ae6d0000x1c573fd3a30000x913f271ca360000x2b1ebf9c80808000']
# [161, 25438, 4197270, 692549550, 116348324400, 14078147252400, 2477753916422400, 416262657958963200, 71180914510982707200, 11744850894312146688000]
# ['0xa1', '0xa10x635e', '0xa10x635e0x400b96', '0xa10x635e0x400b960x294777ae', '0xa10x635e0x400b960x294777ae0x1b16e68a30', '0xa10x635e0x400b960x294777ae0x1b16e68a300xccdd2f750b0', '0xa10x635e0x400b960x294777ae0x1b16e68a300xccdd2f750b00x8cd810a077900', '0xa10x635e0x400b960x294777ae0x1b16e68a300xccdd2f750b00x8cd810a0779000x5c6dcae94e76800', '0xa10x635e0x400b960x294777ae0x1b16e68a300xccdd2f750b00x8cd810a0779000x5c6dcae94e768000x3dbd5689d76927800', '0xa10x635e0x400b960x294777ae0x1b16e68a300xccdd2f750b00x8cd810a0779000x5c6dcae94e768000x3dbd5689d769278000x27cb08c6d7d6c675800']
#
#  D 68 0x44
# ['H', 'E', 'L', 'L', 'O', ' ', 'W', 'O', 'R', 'L', 'D']
# [72, 69, 76, 76, 79, 32, 87, 79, 82, 76, 68]
# [161, 158, 165, 165, 168, 121, 176, 168, 171, 165, 157]
# ['0x48', '0x45', '0x4c', '0x4c', '0x4f', '0x20', '0x57', '0x4f', '0x52', '0x4c', '0x44']
# [72, 4968, 377568, 28695168, 2266918272, 72541384704, 6311100469248, 498576937070592, 40883308839788544, 3107131471823929344, 211284940084027195392]
# ['0x48', '0x480x1368', '0x480x13680x5c2e0', '0x480x13680x5c2e00x1b5da80', '0x480x13680x5c2e00x1b5da800x871e6d80', '0x480x13680x5c2e00x1b5da800x871e6d800x10e3cdb000', '0x480x13680x5c2e00x1b5da800x871e6d800x10e3cdb0000x5bd6ae6d000', '0x480x13680x5c2e00x1b5da800x871e6d800x10e3cdb0000x5bd6ae6d0000x1c573fd3a3000', '0x480x13680x5c2e00x1b5da800x871e6d800x10e3cdb0000x5bd6ae6d0000x1c573fd3a30000x913f271ca36000', '0x480x13680x5c2e00x1b5da800x871e6d800x10e3cdb0000x5bd6ae6d0000x1c573fd3a30000x913f271ca360000x2b1ebf9c80808000', '0x480x13680x5c2e00x1b5da800x871e6d800x10e3cdb0000x5bd6ae6d0000x1c573fd3a30000x913f271ca360000x2b1ebf9c808080000xb742ae59222220000']
# [161, 25438, 4197270, 692549550, 116348324400, 14078147252400, 2477753916422400, 416262657958963200, 71180914510982707200, 11744850894312146688000, 1843941590407007030016000]
# ['0xa1', '0xa10x635e', '0xa10x635e0x400b96', '0xa10x635e0x400b960x294777ae', '0xa10x635e0x400b960x294777ae0x1b16e68a30', '0xa10x635e0x400b960x294777ae0x1b16e68a300xccdd2f750b0', '0xa10x635e0x400b960x294777ae0x1b16e68a300xccdd2f750b00x8cd810a077900', '0xa10x635e0x400b960x294777ae0x1b16e68a300xccdd2f750b00x8cd810a0779000x5c6dcae94e76800', '0xa10x635e0x400b960x294777ae0x1b16e68a300xccdd2f750b00x8cd810a0779000x5c6dcae94e768000x3dbd5689d76927800', '0xa10x635e0x400b960x294777ae0x1b16e68a300xccdd2f750b00x8cd810a0779000x5c6dcae94e768000x3dbd5689d769278000x27cb08c6d7d6c675800', '0xa10x635e0x400b960x294777ae0x1b16e68a300xccdd2f750b00x8cd810a0779000x5c6dcae94e768000x3dbd5689d769278000x27cb08c6d7d6c6758000x18678461f25eb7b60f800']
# Key is:  211284940084027195392
# Hex Key is:  0xb742ae59222220000
# HexKey is:  0x480x13680x5c2e00x1b5da800x871e6d800x10e3cdb0000x5bd6ae6d0000x1c573fd3a30000x913f271ca360000x2b1ebf9c808080000xb742ae59222220000
# Hex_Key is:  0xa10x635e0x400b960x294777ae0x1b16e68a300xccdd2f750b00x8cd810a0779000x5c6dcae94e768000x3dbd5689d769278000x27cb08c6d7d6c6758000x18678461f25eb7b60f800

# %% [markdown]
# Checking if hash 2 and 3 are the same

# %%
print(check2)
print(check3)
if(check3==check2):
    print("Hash matches")
else:
    print("Hash does not match")
# Out:
# 0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a8000xb20f59252ea7238000x8905cf999ce69e518000x65294a4468d642e22b800
# 0xa10x635e0x400b960x294777ae0x1b16e68a300xccdd2f750b00x8cd810a0779000x5c6dcae94e768000x3dbd5689d769278000x27cb08c6d7d6c6758000x18678461f25eb7b60f800
# Hash does not match

# %% [markdown]
# Fourth run of the program using Hello WOrld

# %%
hex_key, size= crypto()
check4= hex_key[size-1]
# Out:
# 17
#
#
#  H 72 0x48
# ['H']
# [72]
# [161]
# ['0x48']
# [72]
# ['0x48']
# [161]
# ['0xa1']
#
#  e 101 0x65
# ['H', 'e']
# [72, 101]
# [161, 190]
# ['0x48', '0x65']
# [72, 7272]
# ['0x48', '0x480x1c68']
# [161, 30590]
# ['0xa1', '0xa10x777e']
#
#  l 108 0x6c
# ['H', 'e', 'l']
# [72, 101, 108]
# [161, 190, 197]
# ['0x48', '0x65', '0x6c']
# [72, 7272, 785376]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0']
# [161, 30590, 6026230]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6']
#
#  l 108 0x6c
# ['H', 'e', 'l', 'l']
# [72, 101, 108, 108]
# [161, 190, 197, 197]
# ['0x48', '0x65', '0x6c', '0x6c']
# [72, 7272, 785376, 84820608]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280']
# [161, 30590, 6026230, 1187167310]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6', '0xa10x777e0x5bf3f60x46c2bc4e']
#
#  o 111 0x6f
# ['H', 'e', 'l', 'l', 'o']
# [72, 101, 108, 108, 111]
# [161, 190, 197, 197, 200]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f']
# [72, 7272, 785376, 84820608, 9415087488]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580']
# [161, 30590, 6026230, 1187167310, 237433462000]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6', '0xa10x777e0x5bf3f60x46c2bc4e', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf0']
#
#    32 0x20
# ['H', 'e', 'l', 'l', 'o', ' ']
# [72, 101, 108, 108, 111, 32]
# [161, 190, 197, 197, 200, 121]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x20']
# [72, 7272, 785376, 84820608, 9415087488, 301282799616]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab000']
# [161, 30590, 6026230, 1187167310, 237433462000, 28729448902000]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6', '0xa10x777e0x5bf3f60x46c2bc4e', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf0', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad70']
#
#  W 87 0x57
# ['H', 'e', 'l', 'l', 'o', ' ', 'W']
# [72, 101, 108, 108, 111, 32, 87]
# [161, 190, 197, 197, 200, 121, 176]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x20', '0x57']
# [72, 7272, 785376, 84820608, 9415087488, 301282799616, 26211603566592]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d000']
# [161, 30590, 6026230, 1187167310, 237433462000, 28729448902000, 5056383006752000]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6', '0xa10x777e0x5bf3f60x46c2bc4e', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf0', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad70', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d00']
#
#  O 79 0x4f
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'O']
# [72, 101, 108, 108, 111, 32, 87, 79]
# [161, 190, 197, 197, 200, 121, 176, 168]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x20', '0x57', '0x4f']
# [72, 7272, 785376, 84820608, 9415087488, 301282799616, 26211603566592, 2070716681760768]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000x75b4e4c3f3000']
# [161, 30590, 6026230, 1187167310, 237433462000, 28729448902000, 5056383006752000, 849472345134336000]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6', '0xa10x777e0x5bf3f60x46c2bc4e', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf0', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad70', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d00', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xbc9ee98e2400800']
#
#  r 114 0x72
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'O', 'r']
# [72, 101, 108, 108, 111, 32, 87, 79, 114]
# [161, 190, 197, 197, 200, 121, 176, 168, 203]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x20', '0x57', '0x4f', '0x72']
# [72, 7272, 785376, 84820608, 9415087488, 301282799616, 26211603566592, 2070716681760768, 236061701720727552]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000x75b4e4c3f3000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000x75b4e4c3f30000x346a8ddf4236000']
# [161, 30590, 6026230, 1187167310, 237433462000, 28729448902000, 5056383006752000, 849472345134336000, 172442886062270208000]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6', '0xa10x777e0x5bf3f60x46c2bc4e', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf0', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad70', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d00', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xbc9ee98e2400800', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xbc9ee98e24008000x95920333b68c65800']
#
#  l 108 0x6c
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'O', 'r', 'l']
# [72, 101, 108, 108, 111, 32, 87, 79, 114, 108]
# [161, 190, 197, 197, 200, 121, 176, 168, 203, 197]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x20', '0x57', '0x4f', '0x72', '0x6c']
# [72, 7272, 785376, 84820608, 9415087488, 301282799616, 26211603566592, 2070716681760768, 236061701720727552, 25494663785838575616]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000x75b4e4c3f3000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000x75b4e4c3f30000x346a8ddf4236000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000x75b4e4c3f30000x346a8ddf42360000x161cf3da2feec8000']
# [161, 30590, 6026230, 1187167310, 237433462000, 28729448902000, 5056383006752000, 849472345134336000, 172442886062270208000, 33971248554267230976000]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6', '0xa10x777e0x5bf3f60x46c2bc4e', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf0', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad70', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d00', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xbc9ee98e2400800', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xbc9ee98e24008000x95920333b68c65800', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xbc9ee98e24008000x95920333b68c658000x73195c76cb7a0a1b800']
#
#  d 100 0x64
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'O', 'r', 'l', 'd']
# [72, 101, 108, 108, 111, 32, 87, 79, 114, 108, 100]
# [161, 190, 197, 197, 200, 121, 176, 168, 203, 197, 189]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x20', '0x57', '0x4f', '0x72', '0x6c', '0x64']
# [72, 7272, 785376, 84820608, 9415087488, 301282799616, 26211603566592, 2070716681760768, 236061701720727552, 25494663785838575616, 2549466378583857561600]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000x75b4e4c3f3000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000x75b4e4c3f30000x346a8ddf4236000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000x75b4e4c3f30000x346a8ddf42360000x161cf3da2feec8000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000x75b4e4c3f30000x346a8ddf42360000x161cf3da2feec80000x8a34f413ab94620000']
# [161, 30590, 6026230, 1187167310, 237433462000, 28729448902000, 5056383006752000, 849472345134336000, 172442886062270208000, 33971248554267230976000, 6420565976756506654464000]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6', '0xa10x777e0x5bf3f60x46c2bc4e', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf0', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad70', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d00', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xbc9ee98e2400800', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xbc9ee98e24008000x95920333b68c65800', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xbc9ee98e24008000x95920333b68c658000x73195c76cb7a0a1b800', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xbc9ee98e24008000x95920333b68c658000x73195c76cb7a0a1b8000x54f9b943b43919764d800']
# Key is:  2549466378583857561600
# Hex Key is:  0x8a34f413ab94620000
# HexKey is:  0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000x75b4e4c3f30000x346a8ddf42360000x161cf3da2feec80000x8a34f413ab94620000
# Hex_Key is:  0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xbc9ee98e24008000x95920333b68c658000x73195c76cb7a0a1b8000x54f9b943b43919764d800

# %% [markdown]
# Check if hash 2 and 4 match

# %%
print(check2)
print(check4)
if(check4==check2):
    print("Hash matches")
else:
    print("Hash does not match")
# Out:
# 0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a8000xb20f59252ea7238000x8905cf999ce69e518000x65294a4468d642e22b800
# 0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xbc9ee98e24008000x95920333b68c658000x73195c76cb7a0a1b8000x54f9b943b43919764d800
# Hash does not match

# %% [markdown]
# Fith run of the program using HelloWorld

# %%
hex_key, size= crypto()
check5= hex_key[size-1]
# Out:
# 95
#
#
#  H 72 0x48
# ['H']
# [72]
# [72]
# ['0x48']
# [72]
# ['0x48']
# [72]
# ['0x48']
#
#  e 101 0x65
# ['H', 'e']
# [72, 101]
# [72, 101]
# ['0x48', '0x65']
# [72, 7272]
# ['0x48', '0x480x1c68']
# [72, 7272]
# ['0x48', '0x480x1c68']
#
#  l 108 0x6c
# ['H', 'e', 'l']
# [72, 101, 108]
# [72, 101, 108]
# ['0x48', '0x65', '0x6c']
# [72, 7272, 785376]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0']
# [72, 7272, 785376]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0']
#
#  l 108 0x6c
# ['H', 'e', 'l', 'l']
# [72, 101, 108, 108]
# [72, 101, 108, 108]
# ['0x48', '0x65', '0x6c', '0x6c']
# [72, 7272, 785376, 84820608]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280']
# [72, 7272, 785376, 84820608]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280']
#
#  o 111 0x6f
# ['H', 'e', 'l', 'l', 'o']
# [72, 101, 108, 108, 111]
# [72, 101, 108, 108, 111]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f']
# [72, 7272, 785376, 84820608, 9415087488]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580']
# [72, 7272, 785376, 84820608, 9415087488]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580']
#
#  W 87 0x57
# ['H', 'e', 'l', 'l', 'o', 'W']
# [72, 101, 108, 108, 111, 87]
# [72, 101, 108, 108, 111, 87]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x57']
# [72, 7272, 785376, 84820608, 9415087488, 819112611456]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e80']
# [72, 7272, 785376, 84820608, 9415087488, 819112611456]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e80']
#
#  o 111 0x6f
# ['H', 'e', 'l', 'l', 'o', 'W', 'o']
# [72, 101, 108, 108, 111, 87, 111]
# [72, 101, 108, 108, 111, 87, 111]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x57', '0x6f']
# [72, 7272, 785376, 84820608, 9415087488, 819112611456, 90921499871616]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e80', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c980']
# [72, 7272, 785376, 84820608, 9415087488, 819112611456, 90921499871616]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e80', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c980']
#
#  r 114 0x72
# ['H', 'e', 'l', 'l', 'o', 'W', 'o', 'r']
# [72, 101, 108, 108, 111, 87, 111, 114]
# [72, 101, 108, 108, 111, 87, 111, 114]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x57', '0x6f', '0x72']
# [72, 7272, 785376, 84820608, 9415087488, 819112611456, 90921499871616, 10365050985364224]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e80', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c980', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb00']
# [72, 7272, 785376, 84820608, 9415087488, 819112611456, 90921499871616, 10365050985364224]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e80', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c980', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb00']
#
#  l 108 0x6c
# ['H', 'e', 'l', 'l', 'o', 'W', 'o', 'r', 'l']
# [72, 101, 108, 108, 111, 87, 111, 114, 108]
# [72, 101, 108, 108, 111, 87, 111, 114, 108]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x57', '0x6f', '0x72', '0x6c']
# [72, 7272, 785376, 84820608, 9415087488, 819112611456, 90921499871616, 10365050985364224, 1119425506419336192]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e80', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c980', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb00', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb000xf88ff912ea2e400']
# [72, 7272, 785376, 84820608, 9415087488, 819112611456, 90921499871616, 10365050985364224, 1119425506419336192]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e80', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c980', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb00', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb000xf88ff912ea2e400']
#
#  d 100 0x64
# ['H', 'e', 'l', 'l', 'o', 'W', 'o', 'r', 'l', 'd']
# [72, 101, 108, 108, 111, 87, 111, 114, 108, 100]
# [72, 101, 108, 108, 111, 87, 111, 114, 108, 100]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x57', '0x6f', '0x72', '0x6c', '0x64']
# [72, 7272, 785376, 84820608, 9415087488, 819112611456, 90921499871616, 10365050985364224, 1119425506419336192, 111942550641933619200]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e80', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c980', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb00', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb000xf88ff912ea2e400', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb000xf88ff912ea2e4000x61183d4b637a11000']
# [72, 7272, 785376, 84820608, 9415087488, 819112611456, 90921499871616, 10365050985364224, 1119425506419336192, 111942550641933619200]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e80', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c980', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb00', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb000xf88ff912ea2e400', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb000xf88ff912ea2e4000x61183d4b637a11000']
# Key is:  111942550641933619200
# Hex Key is:  0x61183d4b637a11000
# HexKey is:  0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb000xf88ff912ea2e4000x61183d4b637a11000
# Hex_Key is:  0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb000xf88ff912ea2e4000x61183d4b637a11000

# %% [markdown]
# Checking if hash 4 and 5 match

# %%
print(check4)
print(check5)
if(check4==check5):
    print("Hash matches")
else:
    print("Hash does not match")
# Out:
# 0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xbc9ee98e24008000x95920333b68c658000x73195c76cb7a0a1b8000x54f9b943b43919764d800
# 0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb000xf88ff912ea2e4000x61183d4b637a11000
# Hash does not match

# %% [markdown]
# Sixth run of the program using Hello World

# %%
hex_key, size= crypto()
check6= hex_key[size-1]
# Out:
# 11
#
#
#  H 72 0x48
# ['H']
# [72]
# [161]
# ['0x48']
# [72]
# ['0x48']
# [161]
# ['0xa1']
#
#  e 101 0x65
# ['H', 'e']
# [72, 101]
# [161, 190]
# ['0x48', '0x65']
# [72, 7272]
# ['0x48', '0x480x1c68']
# [161, 30590]
# ['0xa1', '0xa10x777e']
#
#  l 108 0x6c
# ['H', 'e', 'l']
# [72, 101, 108]
# [161, 190, 197]
# ['0x48', '0x65', '0x6c']
# [72, 7272, 785376]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0']
# [161, 30590, 6026230]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6']
#
#  l 108 0x6c
# ['H', 'e', 'l', 'l']
# [72, 101, 108, 108]
# [161, 190, 197, 197]
# ['0x48', '0x65', '0x6c', '0x6c']
# [72, 7272, 785376, 84820608]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280']
# [161, 30590, 6026230, 1187167310]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6', '0xa10x777e0x5bf3f60x46c2bc4e']
#
#  o 111 0x6f
# ['H', 'e', 'l', 'l', 'o']
# [72, 101, 108, 108, 111]
# [161, 190, 197, 197, 200]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f']
# [72, 7272, 785376, 84820608, 9415087488]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580']
# [161, 30590, 6026230, 1187167310, 237433462000]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6', '0xa10x777e0x5bf3f60x46c2bc4e', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf0']
#
#    32 0x20
# ['H', 'e', 'l', 'l', 'o', ' ']
# [72, 101, 108, 108, 111, 32]
# [161, 190, 197, 197, 200, 121]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x20']
# [72, 7272, 785376, 84820608, 9415087488, 301282799616]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab000']
# [161, 30590, 6026230, 1187167310, 237433462000, 28729448902000]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6', '0xa10x777e0x5bf3f60x46c2bc4e', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf0', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad70']
#
#  W 87 0x57
# ['H', 'e', 'l', 'l', 'o', ' ', 'W']
# [72, 101, 108, 108, 111, 32, 87]
# [161, 190, 197, 197, 200, 121, 176]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x20', '0x57']
# [72, 7272, 785376, 84820608, 9415087488, 301282799616, 26211603566592]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d000']
# [161, 30590, 6026230, 1187167310, 237433462000, 28729448902000, 5056383006752000]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6', '0xa10x777e0x5bf3f60x46c2bc4e', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf0', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad70', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d00']
#
#  o 111 0x6f
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o']
# [72, 101, 108, 108, 111, 32, 87, 111]
# [161, 190, 197, 197, 200, 121, 176, 200]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x20', '0x57', '0x6f']
# [72, 7272, 785376, 84820608, 9415087488, 301282799616, 26211603566592, 2909487995891712]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000xa5629f6793000']
# [161, 30590, 6026230, 1187167310, 237433462000, 28729448902000, 5056383006752000, 1011276601350400000]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6', '0xa10x777e0x5bf3f60x46c2bc4e', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf0', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad70', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d00', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a800']
#
#  r 114 0x72
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r']
# [72, 101, 108, 108, 111, 32, 87, 111, 114]
# [161, 190, 197, 197, 200, 121, 176, 200, 203]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x20', '0x57', '0x6f', '0x72']
# [72, 7272, 785376, 84820608, 9415087488, 301282799616, 26211603566592, 2909487995891712, 331681631531655168]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000xa5629f6793000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000xa5629f67930000x49a5eafc1f76000']
# [161, 30590, 6026230, 1187167310, 237433462000, 28729448902000, 5056383006752000, 1011276601350400000, 205289150074131200000]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6', '0xa10x777e0x5bf3f60x46c2bc4e', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf0', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad70', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d00', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a800', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a8000xb20f59252ea723800']
#
#  l 108 0x6c
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l']
# [72, 101, 108, 108, 111, 32, 87, 111, 114, 108]
# [161, 190, 197, 197, 200, 121, 176, 200, 203, 197]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x20', '0x57', '0x6f', '0x72', '0x6c']
# [72, 7272, 785376, 84820608, 9415087488, 301282799616, 26211603566592, 2909487995891712, 331681631531655168, 35821616205418758144]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000xa5629f6793000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000xa5629f67930000x49a5eafc1f76000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000xa5629f67930000x49a5eafc1f760000x1f11ff225d45c8000']
# [161, 30590, 6026230, 1187167310, 237433462000, 28729448902000, 5056383006752000, 1011276601350400000, 205289150074131200000, 40441962564603846400000]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6', '0xa10x777e0x5bf3f60x46c2bc4e', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf0', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad70', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d00', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a800', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a8000xb20f59252ea723800', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a8000xb20f59252ea7238000x8905cf999ce69e51800']
#
#  d 100 0x64
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd']
# [72, 101, 108, 108, 111, 32, 87, 111, 114, 108, 100]
# [161, 190, 197, 197, 200, 121, 176, 200, 203, 197, 189]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x20', '0x57', '0x6f', '0x72', '0x6c', '0x64']
# [72, 7272, 785376, 84820608, 9415087488, 301282799616, 26211603566592, 2909487995891712, 331681631531655168, 35821616205418758144, 3582161620541875814400]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000xa5629f6793000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000xa5629f67930000x49a5eafc1f76000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000xa5629f67930000x49a5eafc1f760000x1f11ff225d45c8000', '0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000xa5629f67930000x49a5eafc1f760000x1f11ff225d45c80000xc2307a96c6f4220000']
# [161, 30590, 6026230, 1187167310, 237433462000, 28729448902000, 5056383006752000, 1011276601350400000, 205289150074131200000, 40441962564603846400000, 7643530924710126969600000]
# ['0xa1', '0xa10x777e', '0xa10x777e0x5bf3f6', '0xa10x777e0x5bf3f60x46c2bc4e', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf0', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad70', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d00', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a800', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a8000xb20f59252ea723800', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a8000xb20f59252ea7238000x8905cf999ce69e51800', '0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a8000xb20f59252ea7238000x8905cf999ce69e518000x65294a4468d642e22b800']
# Key is:  3582161620541875814400
# Hex Key is:  0xc2307a96c6f4220000
# HexKey is:  0x480x1c680xbfbe00x50e42800x2312ed5800x4625dab0000x17d6dd51d0000xa5629f67930000x49a5eafc1f760000x1f11ff225d45c80000xc2307a96c6f4220000
# Hex_Key is:  0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a8000xb20f59252ea7238000x8905cf999ce69e518000x65294a4468d642e22b800

# %% [markdown]
# Checking if hash 6 and hash 2 match

# %%
print(check2)
print(check6)
if(check6==check2):
    print("Hash matches")
else:
    print("Hash does not match")
# Out:
# 0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a8000xb20f59252ea7238000x8905cf999ce69e518000x65294a4468d642e22b800
# 0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a8000xb20f59252ea7238000x8905cf999ce69e518000x65294a4468d642e22b800
# Hash matches

# %% [markdown]
# Seventh run of the program using Hello

# %%
hex_key, size= crypto()
check7= hex_key[size-1]
# Out:
# 6
#
#
#  H 72 0x48
# ['H']
# [72]
# [185]
# ['0x48']
# [72]
# ['0x48']
# [185]
# ['0xb9']
#
#  e 101 0x65
# ['H', 'e']
# [72, 101]
# [185, 214]
# ['0x48', '0x65']
# [72, 7272]
# ['0x48', '0x480x1c68']
# [185, 39590]
# ['0xb9', '0xb90x9aa6']
#
#  l 108 0x6c
# ['H', 'e', 'l']
# [72, 101, 108]
# [185, 214, 221]
# ['0x48', '0x65', '0x6c']
# [72, 7272, 785376]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0']
# [185, 39590, 8749390]
# ['0xb9', '0xb90x9aa6', '0xb90x9aa60x85814e']
#
#  l 108 0x6c
# ['H', 'e', 'l', 'l']
# [72, 101, 108, 108]
# [185, 214, 221, 221]
# ['0x48', '0x65', '0x6c', '0x6c']
# [72, 7272, 785376, 84820608]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280']
# [185, 39590, 8749390, 1933615190]
# ['0xb9', '0xb90x9aa6', '0xb90x9aa60x85814e', '0xb90x9aa60x85814e0x7340a056']
#
#  o 111 0x6f
# ['H', 'e', 'l', 'l', 'o']
# [72, 101, 108, 108, 111]
# [185, 214, 221, 221, 224]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f']
# [72, 7272, 785376, 84820608, 9415087488]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580']
# [185, 39590, 8749390, 1933615190, 433129802560]
# ['0xb9', '0xb90x9aa6', '0xb90x9aa60x85814e', '0xb90x9aa60x85814e0x7340a056', '0xb90x9aa60x85814e0x7340a0560x64d88c4b40']
# Key is:  9415087488
# Hex Key is:  0x2312ed580
# HexKey is:  0x480x1c680xbfbe00x50e42800x2312ed580
# Hex_Key is:  0xb90x9aa60x85814e0x7340a0560x64d88c4b40

# %% [markdown]
# Checking if Hash 1 and 7 match

# %%
print(check1)
print(check7)
if(check1==check7):
    print("Hash matches")
else:
    print("Hash does not match")
# Out:
# 0xb90x9aa60x85814e0x7340a0560x64d88c4b40
# 0xb90x9aa60x85814e0x7340a0560x64d88c4b40
# Hash matches

# %% [markdown]
# Eigth run of the program using HelloWorld

# %%
hex_key, size= crypto()
check8= hex_key[size-1]
# Out:
# 32
#
#
#  H 72 0x48
# ['H']
# [72]
# [72]
# ['0x48']
# [72]
# ['0x48']
# [72]
# ['0x48']
#
#  e 101 0x65
# ['H', 'e']
# [72, 101]
# [72, 101]
# ['0x48', '0x65']
# [72, 7272]
# ['0x48', '0x480x1c68']
# [72, 7272]
# ['0x48', '0x480x1c68']
#
#  l 108 0x6c
# ['H', 'e', 'l']
# [72, 101, 108]
# [72, 101, 108]
# ['0x48', '0x65', '0x6c']
# [72, 7272, 785376]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0']
# [72, 7272, 785376]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0']
#
#  l 108 0x6c
# ['H', 'e', 'l', 'l']
# [72, 101, 108, 108]
# [72, 101, 108, 108]
# ['0x48', '0x65', '0x6c', '0x6c']
# [72, 7272, 785376, 84820608]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280']
# [72, 7272, 785376, 84820608]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280']
#
#  o 111 0x6f
# ['H', 'e', 'l', 'l', 'o']
# [72, 101, 108, 108, 111]
# [72, 101, 108, 108, 111]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f']
# [72, 7272, 785376, 84820608, 9415087488]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580']
# [72, 7272, 785376, 84820608, 9415087488]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580']
#
#  W 87 0x57
# ['H', 'e', 'l', 'l', 'o', 'W']
# [72, 101, 108, 108, 111, 87]
# [72, 101, 108, 108, 111, 87]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x57']
# [72, 7272, 785376, 84820608, 9415087488, 819112611456]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e80']
# [72, 7272, 785376, 84820608, 9415087488, 819112611456]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e80']
#
#  o 111 0x6f
# ['H', 'e', 'l', 'l', 'o', 'W', 'o']
# [72, 101, 108, 108, 111, 87, 111]
# [72, 101, 108, 108, 111, 87, 111]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x57', '0x6f']
# [72, 7272, 785376, 84820608, 9415087488, 819112611456, 90921499871616]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e80', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c980']
# [72, 7272, 785376, 84820608, 9415087488, 819112611456, 90921499871616]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e80', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c980']
#
#  r 114 0x72
# ['H', 'e', 'l', 'l', 'o', 'W', 'o', 'r']
# [72, 101, 108, 108, 111, 87, 111, 114]
# [72, 101, 108, 108, 111, 87, 111, 114]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x57', '0x6f', '0x72']
# [72, 7272, 785376, 84820608, 9415087488, 819112611456, 90921499871616, 10365050985364224]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e80', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c980', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb00']
# [72, 7272, 785376, 84820608, 9415087488, 819112611456, 90921499871616, 10365050985364224]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e80', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c980', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb00']
#
#  l 108 0x6c
# ['H', 'e', 'l', 'l', 'o', 'W', 'o', 'r', 'l']
# [72, 101, 108, 108, 111, 87, 111, 114, 108]
# [72, 101, 108, 108, 111, 87, 111, 114, 108]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x57', '0x6f', '0x72', '0x6c']
# [72, 7272, 785376, 84820608, 9415087488, 819112611456, 90921499871616, 10365050985364224, 1119425506419336192]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e80', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c980', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb00', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb000xf88ff912ea2e400']
# [72, 7272, 785376, 84820608, 9415087488, 819112611456, 90921499871616, 10365050985364224, 1119425506419336192]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e80', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c980', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb00', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb000xf88ff912ea2e400']
#
#  d 100 0x64
# ['H', 'e', 'l', 'l', 'o', 'W', 'o', 'r', 'l', 'd']
# [72, 101, 108, 108, 111, 87, 111, 114, 108, 100]
# [72, 101, 108, 108, 111, 87, 111, 114, 108, 100]
# ['0x48', '0x65', '0x6c', '0x6c', '0x6f', '0x57', '0x6f', '0x72', '0x6c', '0x64']
# [72, 7272, 785376, 84820608, 9415087488, 819112611456, 90921499871616, 10365050985364224, 1119425506419336192, 111942550641933619200]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e80', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c980', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb00', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb000xf88ff912ea2e400', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb000xf88ff912ea2e4000x61183d4b637a11000']
# [72, 7272, 785376, 84820608, 9415087488, 819112611456, 90921499871616, 10365050985364224, 1119425506419336192, 111942550641933619200]
# ['0x48', '0x480x1c68', '0x480x1c680xbfbe0', '0x480x1c680xbfbe00x50e4280', '0x480x1c680xbfbe00x50e42800x2312ed580', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e80', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c980', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb00', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb000xf88ff912ea2e400', '0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb000xf88ff912ea2e4000x61183d4b637a11000']
# Key is:  111942550641933619200
# Hex Key is:  0x61183d4b637a11000
# HexKey is:  0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb000xf88ff912ea2e4000x61183d4b637a11000
# Hex_Key is:  0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb000xf88ff912ea2e4000x61183d4b637a11000

# %% [markdown]
# Checking if hash 5 and 8 match

# %%
print(check5)
print(check8)
if(check5==check8):
    print("Hash matches")
else:
    print("Hash does not match")
# Out:
# 0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb000xf88ff912ea2e4000x61183d4b637a11000
# 0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb000xf88ff912ea2e4000x61183d4b637a11000
# Hash matches

# %% [markdown]
# All of the hashes

# %%
print(check1)
print(check2)
print(check3)
print(check4)
print(check5)
print(check6)
print(check7)
print(check8)
# Out:
# 0xb90x9aa60x85814e0x7340a0560x64d88c4b40
# 0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a8000xb20f59252ea7238000x8905cf999ce69e518000x65294a4468d642e22b800
# 0xa10x635e0x400b960x294777ae0x1b16e68a300xccdd2f750b00x8cd810a0779000x5c6dcae94e768000x3dbd5689d769278000x27cb08c6d7d6c6758000x18678461f25eb7b60f800
# 0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xbc9ee98e24008000x95920333b68c658000x73195c76cb7a0a1b8000x54f9b943b43919764d800
# 0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb000xf88ff912ea2e4000x61183d4b637a11000
# 0xa10x777e0x5bf3f60x46c2bc4e0x3748231cf00x1a211898ad700x11f6c0e8f73d000xe08c6b60127a8000xb20f59252ea7238000x8905cf999ce69e518000x65294a4468d642e22b800
# 0xb90x9aa60x85814e0x7340a0560x64d88c4b40
# 0x480x1c680xbfbe00x50e42800x2312ed5800xbeb6ea8e800x52b14fb3c9800x24d2f57e0fbb000xf88ff912ea2e4000x61183d4b637a11000

# %% [markdown]
# The database below is unfinished so please ignore

# %%
meta={'Username':['Tyree', 'Ashanti', 'Adrian'],
      'Classification':['Senior', 'Junior', 'Senior'],
      'Exp Grad': ['Spring 2023', 'Fall 2024', 'Spring 2024'],
      'Metadata': ['My name is Tyree Scott and I want to be a database developer.', 
                   'My name is Ashanti Boone and I want to be a software engineer', 'rst567'], 
      'Hash':['0x910x5bc20x4084680x2d5d19200x209aea0f000x166a80ea50000xfac7823d5f0000xa1a296f18e3b0000x47fa6737915646000', 
               '0x680x29080x114f600x74d7c800x32a98fb800xae26de08800x22b1be3bb1800x72ecc625bbf80', 
               '0xd20x9e520x7f65fc0x618a14f00x4edea6ee100x3f284baca2d0' ]}

metadataframe= pd.DataFrame(meta)
print("metadata table")
print(metadataframe)

metadataframe['Username']= metadataframe['Username'].astype(str)

metadataframe.dtypes
# Out:
# metadata table
#   Username Classification     Exp Grad  \
# 0    Tyree         Senior  Spring 2023
# 1  Ashanti         Junior    Fall 2024
# 2   Adrian         Senior  Spring 2024
#
#                                             Metadata  \
# 0  My name is Tyree Scott and I want to be a data...
# 1  My name is Ashanti Boone and I want to be a so...
# 2                                             rst567
#
#                                                 Hash
# 0  0x910x5bc20x4084680x2d5d19200x209aea0f000x166a...
# 1  0x680x29080x114f600x74d7c800x32a98fb800xae26de...
# 2  0xd20x9e520x7f65fc0x618a14f00x4edea6ee100x3f28...
# Username          object
# Classification    object
# Exp Grad          object
# Metadata          object
# Hash              object
# dtype: object

# %%
def password():
    uname= input("Enter the username: \n")
    pword= input("Enter the password:  \n")

    #metadataframe.set_index("Hash", inplace= True)

    #tempdf= dataframe.loc[uname]

    size2= len(pword)

    #setting K as a random int
    k= (random.randint(1, 999999999999)) % 100 +1
    print(k, '\n')

    #setting list
    abcs=[]
    avalue=[]
    hvalue=[]
    keys= []
    hexkey= []
    ravalue= []
    hex_key=[]
    rakey=[]
    rahvalue= []

    count= 0 

    if (k % 2 == 0 or k % 3 == 0 or k % 5 == 0 or k % 7 == 0):
        k= random.randint(1, 999999999999) % 100 + 1
    for i in pword:
            print("\n", i, ord(i), hex(ord(i)))
            #characters added to a list
            abcs.append(i)
            #ascii value added to a lis
            avalue.append(ord(i))
            #acii value plus (size^size-1)%128
            ravalue.append(ord(i)+ pow(size2,size2-1,128))
            #hexi value of ascii value
            hvalue.append(hex(ord(i)))
            #hexi value of ascii value plus (size ^ size-1)%128
            rahvalue.append(hex(ord(i)+ pow(size2,size2-1,128)))
            
            if(count==0):
                #adding the first ascii value to a list of keys 
                keys.append(avalue[count])
                #adding the first hex value of the ascii value to  a list of keys
                hexkey.append(hex(avalue[count]))
                #adding the first ascii value plus ... to a list of keys
                rakey.append(ravalue[count])
                #adding the first hex value of the ascii value plus ... to a list of keys
                hex_key.append(hex(ravalue[count]))
            else:
                #adding a key to the list by multiplying the current ascii value by the previous key cell value
                keys.append(avalue[count]* keys[count- 1])
                #adding a hex key to the list by concating the previous key value to the hex value of 
                #the current asciii value of the character times the previous ascii key cell
                hexkey.append(hexkey[count- 1]+ hex(avalue[count]* keys[count- 1]))
                #adding a key to the list by multiplying the current ascii value plus... by the previous rakey cell value 
                rakey.append(ravalue[count]* rakey[count-1])
                #adding a hex key to the list by concating the previous key value to the hex value of 
                #the current ravalue of the character times the previous rakey cell
                hex_key.append(hex_key[count- 1]+ hex(ravalue[count]* rakey[count- 1]))
        
            #incrimenting count 
            count= count +1
    print("Key is: ", keys[size2-1])
    print("Hex Key is: ", hex(keys[size2-1]))
    print("HexKey is: ", hexkey[size2-1])
    print("Hex_Key is: ", hex_key[size2-1])
    return [hex_key, size2, uname]

phex_key, size2, uname= password()
hashcheck= phex_key[size2-1]
print(hashcheck)
# Out:
# 28
#
#
#  P 80 0x50
#
#  a 97 0x61
#
#  s 115 0x73
#
#  s 115 0x73
#
#  w 119 0x77
#
#  o 111 0x6f
#
#  r 114 0x72
#
#  d 100 0x64
#
#  2 50 0x32
# Key is:  772684495380000000
# Hex Key is:  0xab920746693ad00
# HexKey is:  0x500x1e500xd9df00x61df2d00x2d7ebdeb00x13b9f458e500x8c8cecf95fa00x36e70c91695a800xab920746693ad00
# Hex_Key is:  0x910x5bc20x4084680x2d5d19200x209aea0f000x166a80ea50000xfac7823d5f0000xa1a296f18e3b0000x489c09ce82e481000
# 0x910x5bc20x4084680x2d5d19200x209aea0f000x166a80ea50000xfac7823d5f0000xa1a296f18e3b0000x489c09ce82e481000

# %%
display(metadataframe.loc[(metadataframe['Hash']==hashcheck) & (metadataframe['Username']==uname),
                    ['Username','Classification', 'Exp Grad', 'Metadata']])
# Out:
#   Username Classification     Exp Grad  \
# 0    Tyree         Senior  Spring 2023
#
#                                             Metadata
# 0  My name is Tyree Scott and I want to be a data...
